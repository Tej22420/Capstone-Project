# %% [markdown]
# Movies that cost over 100 million can still fail, why so? Movie lovers might have different interests. will be highly rated, etc.
# A production company wants to analyze a movie dataset to identify what kinds of movies perform well in cinemas, which genres they belong to, and so on. It will help the company predict if a movie will be a commercial success, if the movie will be highly rated etc.
#
# #### Data Dictionary
# 1. Budget: The budget of a movie in dollars. (A budget value of 0 means the budget value is unknown.)
# 2. Genres: The genre of the movie and TMDB id (in JSON format)
# 3. Homepage: The official homepage URL of a movie
# 4. Id: IMDB id of a movie (string)
# 5. Keywords: TMDB id and names of all keywords (in JSON format)
# 6. Original_language: Two-digit code of the original language (the language in which the movie was made) such as, en for English, fr for French
# 7. Original_title: The original title of a movie. The title and original title of a movie may differ if the original title is not in English.
# 8. Popularity: Popularity of the movie (in float)
# 9. Overview: Brief description of the movie
# 10. Production_companies: All production companies' names and TMDB id of a movie (in JSON format)
# 11. Production_countries: Two-digit code and the full name of the production country (in JSON format)
# 12. Release_date: The release date of a movie (in dd/mm/yy format)
# 13. Revenue: The total revenue earned by a movie (in dollars)
# 14. Runtime: The total runtime of a movie in minutes (integer)
# 15. Spoken_languages: Two-digit code and the full name of the spoken language
# 16. Status: The status of the movie (postproduction, released, or rumored)
# 17. Vote_average: Average vote for a movie
# 18. Vote_count: The total vote count for a movie
# 19. Tagline: Tagline of a movie
# 20. Title: English title of a movie

# %%
import matplotlib.pyplot as plt             # to visualize
from tabulate import tabulate               # to print the table
import matplotlib as mat                    # to visualize 
import seaborn as sns                       # to visualize
import pandas as pd                         # for data reading
import numpy as np      
import statistics as st
import warnings
warnings.filterwarnings('ignore')
print("Imported the required packages")
# Out:
# Imported the required packages

# %% [markdown]
# ### Task-1

# %%
#### Load the dataset
df = pd.read_csv("DS1_C8_V3_ND_Sprint2_Data Analysis Using Python_Dataset.csv")
df
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
#### Displaying the number of rows and columns
df.shape
# Out:
# (4803, 20)

# %%
##### Displaying the title and genres of first 50.
selected_columns = df[["title", "genres"]].head(50)
selected_columns
# Out:
#                                           title  \
# 0                                        Avatar
# 1      Pirates of the Caribbean: At World's End
# 2                                       Spectre
# 3                         The Dark Knight Rises
# 4                                   John Carter
# 5                                  Spider-Man 3
# 6                                       Tangled
# 7                       Avengers: Age of Ultron
# 8        Harry Potter and the Half-Blood Prince
# 9            Batman v Superman: Dawn of Justice
# 10                             Superman Returns
# 11                            Quantum of Solace
# 12   Pirates of the Caribbean: Dead Man's Chest
# 13                              The Lone Ranger
# 14                                 Man of Steel
# 15     The Chronicles of Narnia: Prince Caspian
# 16                                 The Avengers
# 17  Pirates of the Caribbean: On Stranger Tides
# ...

# %% [markdown]
# ### Task-2

# %%
### Checking for NULL values
df.isnull().sum()
# Out:
# budget                     0
# genres                     0
# homepage                3091
# id                         0
# keywords                   0
# original_language          0
# original_title             0
# overview                   3
# popularity                 0
# production_companies       0
# production_countries       0
# release_date               1
# revenue                    0
# runtime                    2
# spoken_languages           0
# status                     0
# tagline                  844
# title                      0
# vote_average               0
# vote_count                 0
# dtype: int64

# %% [markdown]
# #### We got 5 columns with NULL values
# 1. homepage
# 2. overview
# 3. release_date
# 4. runtime
# 5. tagline

# %%
#### Treating the NULL values
mode_value = df["homepage"].mode()[0]

# Fill missing values with the mode value
df["homepage"].fillna(value=mode_value, inplace=True)

# %%
mode_value = df["overview"].mode()[0]

# Fill missing values with the mode value
df["overview"].fillna(value=mode_value, inplace=True)

# %%
df["runtime"].fillna(value =df["runtime"].mean(),inplace = True)

# %%
mode_value = df["release_date"].mode()[0]

# Fill missing values with the mode value
df["release_date"].fillna(value=mode_value, inplace=True)

# %%
mode_value = df["tagline"].mode()[0]

# Fill missing values with the mode value
df["tagline"].fillna(value=mode_value, inplace=True)

# %%
#### Again checking for any NULL values
df.isnull().sum()
# Out:
# budget                  0
# genres                  0
# homepage                0
# id                      0
# keywords                0
# original_language       0
# original_title          0
# overview                0
# popularity              0
# production_companies    0
# production_countries    0
# release_date            0
# revenue                 0
# runtime                 0
# spoken_languages        0
# status                  0
# tagline                 0
# title                   0
# vote_average            0
# vote_count              0
# dtype: int64

# %%
#### No NULL values found.

# %% [markdown]
# ### Task-3

# %%
filtered_movies = df[df['budget'] >= 220000]
categories = filtered_movies['genres'].unique()
for category in categories:
    print(category)
# Out:
# [{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]
# [{"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 28, "name": "Action"}]
# [{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 80, "name": "Crime"}]
# [{"id": 28, "name": "Action"}, {"id": 80, "name": "Crime"}, {"id": 18, "name": "Drama"}, {"id": 53, "name": "Thriller"}]
# [{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 878, "name": "Science Fiction"}]
# [{"id": 14, "name": "Fantasy"}, {"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}]
# [{"id": 16, "name": "Animation"}, {"id": 10751, "name": "Family"}]
# [{"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 10751, "name": "Family"}]
# [{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}]
# ...

# %% [markdown]
# ### Task-4

# %%
filtered_movies = df[df['revenue'] >= 961000000]
categories = filtered_movies['genres'].unique()
for category in categories:
    print(category)
# Out:
# [{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]
# [{"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 28, "name": "Action"}]
# [{"id": 28, "name": "Action"}, {"id": 80, "name": "Crime"}, {"id": 18, "name": "Drama"}, {"id": 53, "name": "Thriller"}]
# [{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 878, "name": "Science Fiction"}]
# [{"id": 878, "name": "Science Fiction"}, {"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}]
# [{"id": 12, "name": "Adventure"}, {"id": 28, "name": "Action"}, {"id": 14, "name": "Fantasy"}]
# [{"id": 18, "name": "Drama"}, {"id": 10749, "name": "Romance"}, {"id": 53, "name": "Thriller"}]
# [{"id": 12, "name": "Adventure"}, {"id": 28, "name": "Action"}, {"id": 878, "name": "Science Fiction"}]
# ...

# %% [markdown]
# ### Task-5

# %%
df = df[(df['budget'] != 0) | (df['revenue'] != 0)]
df
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4791         13                     [{"id": 27, "name": "Horror"}]
# 4792      20000  [{"id": 80, "name": "Crime"}, {"id": 27, "name...
# 4796       7000  [{"id": 878, "name": "Science Fiction"}, {"id"...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
#
#                                           homepage      id  \
# 0                      http://www.avatarmovie.com/   19995
# ...

# %% [markdown]
# ### Task-6

# %%
highest_movies = df.nlargest(10, 'revenue')
print("Top 10 movies with highest revenue:")
highest_movies
# Out:
# Top 10 movies with highest revenue:
#         budget                                             genres  \
# 0    237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 25   200000000  [{"id": 18, "name": "Drama"}, {"id": 10749, "n...
# 16   220000000  [{"id": 878, "name": "Science Fiction"}, {"id"...
# 28   150000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 44   190000000                     [{"id": 28, "name": "Action"}]
# 7    280000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 124  150000000  [{"id": 16, "name": "Animation"}, {"id": 12, "...
# 31   200000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 546   74000000  [{"id": 10751, "name": "Family"}, {"id": 16, "...
# 26   250000000  [{"id": 12, "name": "Adventure"}, {"id": 28, "...
#
#                                               homepage      id  \
# 0                          http://www.avatarmovie.com/   19995
# 25                         http://www.titanicmovie.com     597
# ...

# %%
least_budget = df.nsmallest(10, 'budget')
print("The top 10 movies with the least budget are:")
least_budget
# Out:
# The top 10 movies with the least budget are:
#      budget                                             genres  \
# 321       0                     [{"id": 35, "name": "Comedy"}]
# 359       0  [{"id": 12, "name": "Adventure"}, {"id": 16, "...
# 409       0  [{"id": 18, "name": "Drama"}, {"id": 10402, "n...
# 475       0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 489       0  [{"id": 99, "name": "Documentary"}, {"id": 107...
# 542       0  [{"id": 28, "name": "Action"}, {"id": 18, "nam...
# 691       0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 766       0  [{"id": 16, "name": "Animation"}, {"id": 35, "...
# 847       0                     [{"id": 35, "name": "Comedy"}]
# 882       0  [{"id": 18, "name": "Drama"}, {"id": 10749, "n...
#
#                                               homepage      id  \
# 321                  http://www.missionimpossible.com/   77953
# 359  http://www.foxmovies.com/movies/alvin-and-the-...  258509
# ...

# %% [markdown]
# ### Task-7

# %%
# Display the correlation as a heatmap
data = df[['popularity', 'budget']]
correlation_matrix = data.corr()
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap Between Popularity and Budget')
plt.show()

# Print the correlation value
correlation = correlation_matrix.loc['popularity', 'budget']
print(f"The correlation between popularity and budget is: {correlation}")
# Out:
# The correlation between popularity and budget is: 0.4603584105467273

# %%
fig,ax = plt.subplots(figsize=(10,6))
sns.heatmap(df.corr(),annot= True ,cmap="Blues_r", cbar = True,linewidth=0.3)
plt.show()

# %% [markdown]
# ### Task-8

# %%
import json
# Convert the string representation of production companies into a list of dictionaries
df['production_companies'] = df['production_companies'].apply(lambda x: json.loads(x))

# %%
# # Initialize an empty dictionary to store production company names and their counts
production_counts = {}

# Iterate over each row in the DataFrame
for row in df.itertuples(index=False):
    # Iterate over each production company in the row
    for company in row.production_companies:
        # Extract the production company name
        company_name = company['name']
        
        # Increment the count for the production company
        if company_name in production_counts:
            production_counts[company_name] += 1
        else:
            production_counts[company_name] = 1

# Create a new DataFrame to store the production company names and their counts
production_df = pd.DataFrame({'Production Company': list(production_counts.keys()), 'Count': list(production_counts.values())})

# Sort the DataFrame by count in descending order
production_df = production_df.sort_values('Count', ascending=False)
production_df
# Out:
#                           Production Company  Count
# 11                              Warner Bros.    302
# 52                        Universal Pictures    294
# 38                        Paramount Pictures    271
# 1     Twentieth Century Fox Film Corporation    213
# 7                          Columbia Pictures    183
# ...                                      ...    ...
# 2011                   American Film Company      1
# 2012                                  Fabula      1
# 2013                             Half Circle      1
# 2015                               Filmtribe      1
# 4358                           Daiei Studios      1
#
# [4359 rows x 2 columns]

# %% [markdown]
# ### Task-9

# %%
# Select the top 25 production companies
production_df = production_df.sort_values('Count', ascending=False)
production_df.head(25)
# Out:
#                           Production Company  Count
# 11                              Warner Bros.    302
# 52                        Universal Pictures    294
# 38                        Paramount Pictures    271
# 1     Twentieth Century Fox Film Corporation    213
# 7                          Columbia Pictures    183
# 46                           New Line Cinema    152
# 4                       Walt Disney Pictures    109
# 49                 Metro-Goldwyn-Mayer (MGM)    108
# 200                      Touchstone Pictures    102
# 54                          Relativity Media    102
# 257            Columbia Pictures Corporation     93
# 391                            Miramax Films     80
# 112                Village Roadshow Pictures     76
# 80                            DreamWorks SKG     69
# 532                           United Artists     67
# 296                      Regency Enterprises     65
# 370                                   Canal+     61
# ...

# %% [markdown]
# ### Task-10

# %%
# Sort the data in descending order based on revenue and filter the top 500 movies
top_500_movies = df.nlargest(500, 'revenue')

# Calculate the measures of central tendency for budget, revenue, and runtime
budget_mean = top_500_movies['budget'].mean()
budget_median = top_500_movies['budget'].median()
budget_mode = top_500_movies['budget'].mode().values[0]

revenue_mean = top_500_movies['revenue'].mean()
revenue_median = top_500_movies['revenue'].median()
revenue_mode = top_500_movies['revenue'].mode().values[0]

runtime_mean = top_500_movies['runtime'].mean()
runtime_median = top_500_movies['runtime'].median()
runtime_mode = top_500_movies['runtime'].mode().values[0]

# Perform outlier analysis using box plots
plt.figure(figsize=(10, 6))
plt.subplot(1, 3, 1)
plt.boxplot(top_500_movies['budget'], vert=False)
plt.title('Budget Box Plot')

plt.subplot(1, 3, 2)
plt.boxplot(top_500_movies['revenue'], vert=False)
plt.title('Revenue Box Plot')

plt.subplot(1, 3, 3)
plt.boxplot(top_500_movies['runtime'], vert=False)
plt.title('Runtime Box Plot')

plt.show()

# Display the measures of central tendency
print(f"Budget Mean: {budget_mean}, Median: {budget_median}, Mode: {budget_mode}")
print(f"Revenue Mean: {revenue_mean}, Median: {revenue_median}, Mode: {revenue_mode}")
print(f"Runtime Mean: {runtime_mean}, Median: {runtime_median}, Mode: {runtime_mode}")
# Out:
# Budget Mean: 102803736.0, Median: 95000000.0, Mode: 150000000
# Revenue Mean: 458722133.294, Median: 363001569.5, Mode: 219076518
# Runtime Mean: 118.626, Median: 116.0, Mode: 115.0

# %% [markdown]
# ### Task-11

# %%
# Calculate the average runtime
average_runtime = top_500_movies['runtime'].mean()

# Filter movies with runtimes above the average
above_average_runtime_movies = top_500_movies[top_500_movies['runtime'] > average_runtime]

# Create a DataFrame with movie names and runtimes
result_df = above_average_runtime_movies[['title','runtime']]

# Display the DataFrame
result_df
# Out:
#                            title  runtime
# 0                         Avatar    162.0
# 25                       Titanic    194.0
# 16                  The Avengers    143.0
# 28                Jurassic World    124.0
# 44                     Furious 7    137.0
# ...                          ...      ...
# 1161          The Social Network    120.0
# 912   Interview with the Vampire    123.0
# 521                 The Terminal    128.0
# 397             It's Complicated    121.0
# 1744                  Knocked Up    129.0
#
# [232 rows x 2 columns]

# %% [markdown]
# ### Task-12- What is the average runtime of the movies?

# %%
average_runtime = df['runtime'].mean()
print(f"The average runtime of movies is {average_runtime:.2f} minutes.")
# Out:
# The average runtime of movies is 109.08 minutes.

# %% [markdown]
# ### Task-13- Relationship between Votecount and Revenue

# %%
ratings = df['vote_count']
earnings = df['revenue']

# Create a scatter plot.
plt.figure(figsize=(10, 6))
plt.scatter(ratings, earnings, alpha=0.5, color='blue')
plt.xlabel("Movie Ratings")
plt.ylabel("Box Office Earnings (in billions)")
plt.title("Movie Ratings vs. Box Office Earnings")
plt.grid(True)
plt.show()

# %% [markdown]
# ### Task-14- What languages are being used the most?

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='original_language', palette="viridis", order=df['original_language'].value_counts().index)
plt.xlabel("Original Language")
plt.ylabel("Count")
plt.title("Distribution of Original Languages")
plt.xticks(rotation=45)
plt.show()
